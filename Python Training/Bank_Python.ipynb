# %% [markdown]
# **Task** **2**

# %%
import numpy as np
import pandas as pd
#Range No(1000, 100000) indicates Adult
class BankAccount_Adult:
    def __init__(self,username,full_name,IC_number,city,no_telephone,
                 total_saving=20,no_id=0):
        self.total_saving=total_saving
        self.username=username
        self.full_name=full_name
        self.IC_number=IC_number
        self.city=city
        self.no_telephone=no_telephone
        no_id=np.random.randint(1000, 100000)
        no_id!=no_id
        print(f"[No.{no_id}] Hello, {username.title()}")
        print(f"Information:{full_name},IC:{IC_number}\nCity:{city}\nNo:{no_telephone}")
    def deposit(self,amount):
        self.total_saving+=amount
        print(f"rm{amount} is amount that your put")
        print(f"rm{self.total_saving} this is your new saving")
    def withdraw(self,draw,minimum_saving=20):
        if self.total_saving-draw<minimum_saving:
         print("Your money in the bank is not enough")
        else:
         print(f"rm{draw} is amount that your draw")
         self.total_saving-=draw
         print(f"check_balance :rm{self.total_saving}")
    def check_balance(self):
      return(f"Balance money remaining:{self.total_saving}")
#Range No(1, 999) indicates child
class BankAccount_child:
    def __init__(self,parent_name,child_full_name,IC_number,city,no_telephone,
                 total_saving=20,no_id=0):
        self.total_saving=total_saving
        self.parent_name=parent_name
        self.child_full_name=child_full_name
        self.IC_number=IC_number
        self.city=city
        self.no_telephone=no_telephone
        no_id=np.random.randint(1, 999)
        no_id!=no_id
        print(f"[No.{no_id}] Hello, Mr/Mrs{parent_name.title()}")
        print(f"Your Son Information:{child_full_name},IC:{IC_number}\nCity:{city}\nNo:{no_telephone}")
    def deposit(self,amount):
        self.total_saving+=amount
        print(f"rm{amount} is amount that your put")
        print(f"rm{self.total_saving} this is your new saving")
    def withdraw(self,draw):
        if draw>self.total_saving:
         print("Your money in the bank is not enough")
        else:
         print(f"{self.parent_name} take amount rm{draw} from your child acc")
         self.total_saving-=draw
         print(f"check_balance :rm{self.total_saving}")
    def check_balance(self):
      return(f"Balance money remaining:{self.total_saving}")
# Create five instances of the BankAccount_Adult class
account1=BankAccount_Adult("Syed","Syed Norman Daniel",999908095444,"Taiping"
                           ,+601111461847)
account1.deposit(500)
account1.withdraw(1000)
account2=BankAccount_Adult("Yura","Wernher Yura Goffredo",8383746282,"Frankurt"
                           ,+90674839292)
account2.deposit(900)
account2.withdraw(700)
account3=BankAccount_Adult("Imran","Imran Iskandar Danial",911107045432,"Kuala Lumpur"
                           ,+60119087445)
account3.deposit(1000)
account3.withdraw(100)
account4=BankAccount_Adult("Ali","Ahmad Ali Idris",800731019999,"kangar",
                            +60839390134)
account4.deposit(1310)
account4.withdraw(1300)
account5=BankAccount_Adult("Faisal","Faisal Nor Sulaiman ",711111095447,"Batukurau",
                           +605463738289)
account5.deposit(1300)
account5.withdraw(1000)
# Create five instances of the BankAccount_child class
account6=BankAccount_child("Syed","Syed Hafiz Daniel",109908095000,"Taiping"
                           ,+601111461847)
account6.deposit(320)
account6.withdraw(400)
account7=BankAccount_child("Yura","Werneir Golp",15837469409,"sttugart"
                           ,+950674839292)
account7.deposit(500)
account7.withdraw(100)
account8=BankAccount_child("Ali","Omar Sabri ",120108039473,"Kuala Lumpur"
                           ,+603456532675)
account8.deposit(1000)
account8.withdraw(0)
account9=BankAccount_child("Faisal","Cahaya Omar Harun",187310099439,"Sabak Bernam",
                            +608393901344)
account9.deposit(800)
account9.withdraw(780)
account10=BankAccount_child("Faisal","Rahman Ismail ",190302089238,"Ijok",
                            +602389678923)
account10.check_balance()
#create an account
#account = BankAccount_Adult("Syed Norman Daniel","Abu")
#Add saving
#account.deposit(2000)
#remove
#account.withdraw(80)
#check
#print(account.check_balance())
# Out:
# [No.98670] Hello, Syed
# Information:Syed Norman Daniel,IC:999908095444
# City:Taiping
# No:601111461847
# rm500 is amount that your put
# rm520 this is your new saving
# Your money in the bank is not enough
# [No.74720] Hello, Yura
# Information:Wernher Yura Goffredo,IC:8383746282
# City:Frankurt
# No:90674839292
# rm900 is amount that your put
# rm920 this is your new saving
# rm700 is amount that your draw
# check_balance :rm220
# [No.21141] Hello, Imran
# Information:Imran Iskandar Danial,IC:911107045432
# City:Kuala Lumpur
# No:60119087445
# rm1000 is amount that your put
# rm1020 this is your new saving
# rm100 is amount that your draw
# check_balance :rm920
# [No.29559] Hello, Ali
# Information:Ahmad Ali Idris,IC:800731019999
# City:kangar
# No:60839390134
# rm1310 is amount that your put
# rm1330 this is your new saving
# rm1300 is amount that your draw
# check_balance :rm30
# [No.14647] Hello, Faisal
# Information:Faisal Nor Sulaiman ,IC:711111095447
# City:Batukurau
# ...
